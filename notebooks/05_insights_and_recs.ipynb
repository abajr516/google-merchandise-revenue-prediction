# %% [markdown]
# Pull together key findings into a narrative: what the business should do differently
# Final polished visuals, summary tables — this is the notebook a hiring manager is most likely to actually read end-to-end
